# %% [markdown]
# # IT Academy - Data Science amb Python
# ## Tasca 5: Exploració de les dades
#
# ###  [Github Exploració de les dades](https://github.com/jesussantana/estructures_Dataframe)

# %% [markdown]
# ###  Exercici 1
# - Descarrega el data set Airlines Delay: [Airline on-time statistics and delay causes](https://www.kaggle.com/giovamata/airlinedelaycauses) i carrega’l a un pandas Dataframe. Explora les dades que conté, i queda’t únicament amb les columnes que consideris rellevants.

# %%
import numpy as np
import pandas as pd
import datetime

dataAirlines = pd.read_csv('DelayedFlights.csv')
dataAirlines
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
dataAirlines.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
pd.set_option('display.max_columns', None)

dataAirlines.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0   2211.0        2225            WN        335  N712SW              128.0
# 1   1002.0        1000            WN       3231  N772SW              128.0
# 2    804.0         750            WN        448  N428WN               96.0
# 3   1959.0        1925            WN       3920  N464WN               90.0
# 4   2121.0        2110            WN        378  N726SW              101.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# ...

# %%
print(dataAirlines.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
#  15  ArrDelay           float64
#  16  DepDelay           float64
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  TaxiIn             float64
#  21  TaxiOut            float64
#  22  Cancelled          int64
#  23  CancellationCode   object
# ...

# %%
# Columnas relevantes

dataAirlines=dataAirlines[['Year','Month','DayofMonth','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier','FlightNum','TailNum','AirTime','ArrDelay','Distance','Cancelled','CancellationCode']].copy()

# %%
dataAirlines.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  FlightNum TailNum  AirTime  ArrDelay  Distance  Cancelled  \
# 0            WN        335  N712SW    116.0     -14.0       810          0
# 1            WN       3231  N772SW    113.0       2.0       810          0
# 2            WN        448  N428WN     76.0      14.0       515          0
# 3            WN       3920  N464WN     77.0      34.0       515          0
# 4            WN        378  N726SW     87.0      11.0       688          0
#
#   CancellationCode
# 0                N
# 1                N
# 2                N
# ...

# %%
dataAirlines['DayofMonthT'] = dataAirlines['DayofMonth'].apply(lambda x: x.zfill(2))
dataAirlines['MonthT'] = dataAirlines['Month'].apply(lambda x: x.zfill(2))
dataAirlines['fechacompl'] = pd.to_datetime(dataAirlines['Year'] + dataAirlines['Month'] + dataAirlines['DayofMonth'],format = '%Y%m%d' )

# %% [markdown]
# ###  Exercici 2
# - Fes un informe complet del data set:
#   - Resumeix estadísticament les columnes d’interès

# %%
dataAirlines.describe().round(3)
# Out:
#             Year        Month   DayofMonth      DepTime   CRSDepTime  \
# count  1936758.0  1936758.000  1936758.000  1936758.000  1936758.000
# mean      2008.0        6.111       15.753     1518.534     1467.473
# std          0.0        3.483        8.776      450.485      424.767
# min       2008.0        1.000        1.000        1.000        0.000
# 25%       2008.0        3.000        8.000     1203.000     1135.000
# 50%       2008.0        6.000       16.000     1545.000     1510.000
# 75%       2008.0        9.000       23.000     1900.000     1815.000
# max       2008.0       12.000       31.000     2400.000     2359.000
#
#            ArrTime   CRSArrTime    FlightNum      AirTime     ArrDelay  \
# count  1929648.000  1936758.000  1936758.000  1928371.000  1928371.000
# mean      1610.141     1634.225     2184.263      108.277       42.200
# std        548.178      464.635     1944.702       68.643       56.785
# ...

# %% [markdown]
#   - Troba quantes dades faltants hi ha per columna

# %%
dataAirlines.isna().sum()
# Out:
# Year                   0
# Month                  0
# DayofMonth             0
# DepTime                0
# CRSDepTime             0
# ArrTime             7110
# CRSArrTime             0
# UniqueCarrier          0
# FlightNum              0
# TailNum                5
# AirTime             8387
# ArrDelay            8387
# Distance               0
# Cancelled              0
# CancellationCode       0
# dtype: int64

# %% [markdown]
#   - Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)

# %%
milesmtokmh = 60 / 0.62137

dataAirlines['AirTime'] = dataAirlines[dataAirlines['AirTime'].notnull()]['AirTime'].apply(lambda s: int(s[:s.find(".")]))

dataAirlines['AverageSpeed'] = dataAirlines['Distance'] * milesmtokmh / (dataAirlines['AirTime'])

dataAirlines['AverageSpeed'].head()

# %% [markdown]
# - Taula de les aerolínies amb més endarreriments acumulats

# %% [markdown]
# - Quins són els vols més llargs? I els més endarrerits?
# - Etc.

# %%
dataAirlinesLong = dataAirlines.copy()
dataAirlinesLong.sort_values(by ='Distance', ascending=False)
# Out:
#          Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 1255581  2008      7          18   2001.0        1955   1126.0        1130
# 1926346  2008     12          20   2333.0        2055   1348.0        1120
# 718062   2008      4          25   1345.0        1335   1826.0        1810
# 1928077  2008     12          16   2135.0        2055   1148.0        1120
# 173695   2008      1          13   1326.0        1320   1912.0        1920
# ...       ...    ...         ...      ...         ...      ...         ...
# 1456273  2008      9          22   1340.0        1325   1553.0        1425
# 47146    2008      1           2   1245.0        1025   1340.0        1125
# 521905   2008      3          12    955.0         931   1021.0         948
# 774654   2008      5          15   2037.0        1800   2125.0        1900
# 1310766  2008      8          10   1315.0        1220   1415.0        1320
#
# ...

# %%
longerFlights = dataAirlinesLong.sort_values(by ='Distance', ascending = False)
longerFlights[['FlightNum','TailNum','Distance']]
# Out:
#          FlightNum TailNum  Distance
# 1255581         14  N67058      4962
# 1926346         14  N66056      4962
# 718062          15  N69059      4962
# 1928077         14  N76054      4962
# 173695          15  N67058      4962
# ...            ...     ...       ...
# 1456273       6898  N710CA        30
# 47146         5610  N806CA        24
# 521905        2009  91619E        24
# 774654        4988  N806CA        11
# 1310766       5572  N819CA        11
#
# [1936758 rows x 3 columns]

# %% [markdown]
# ###  Exercici 3
# - Exporta el data set net i amb les noves columnes a Excel.

# %%
# to_excel

dataAirlines.describe().round(3).to_excel('output1.xlsx', engine='xlsxwriter')

# %%
#to_csv

compression_opts = dict(method='zip', archive_name='out.csv')  
dataAirlines.describe().round(3).to_csv('out.zip', index=False, compression=compression_opts)
